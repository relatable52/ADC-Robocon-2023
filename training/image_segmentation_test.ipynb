# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
import os
from IPython import display
display.clear_output()
# !yolo checks

from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# Import data from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SJ9akUcpitBrkjjW4C1Y")
project = rf.workspace("hello-7gpxt").project("robocon-2023")
dataset = project.version(1).download("yolov8")

# %%
# !yolo task=segment mode=train model=yolov8n-seg.pt data={dataset.location}/data.yaml epochs=15 imgsz=640

# %%
# !yolo task=segment mode=val model=/content/runs/segment/train2/weights/best.pt conf=0.4 data={dataset.location}/data.yaml

# %%
# !yolo task=segment mode=predict model=/content/runs/segment/train2/weights/best.pt save=True conf=0.4 source={dataset.location}/test/images
